# %%
pip install google-cloud-bigquery

# %%
pip install pandas

# %%
import os

# from google cloud import big query
from google.cloud import bigquery
from google.oauth2 import service_account

import pandas as pd

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/Users/tararosen/Documents/data_science/big_query_notebook/key/citibike_key.json'

# %%
# instantiates a client for bigquery service
client = bigquery.Client()

# %%
# query for bigquery
query = """SELECT * FROM `bigquery-public-data.new_york_citibike.citibike_trips` LIMIT 10"""

# run the query and get data from bigquery
query_job = client.query(query)     # API request

# into dataframe

df = query_job.to_dataframe()

# %%
df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           370 2013-10-08 17:59:20.000 2013-10-08 18:05:30.000
# 1           783 2017-09-11 16:06:49.000 2017-09-11 16:19:53.000
# 2          1020 2017-08-22 11:26:36.000 2017-08-22 11:43:37.000
# 3           664 2015-07-27 23:54:05.000 2015-07-28 00:05:10.000
# 4           381 2018-01-30 06:50:35.739 2018-01-30 06:56:57.094
#
#    start_station_id        start_station_name  start_station_latitude  \
# 0               375   Mercer St & Bleecker St               40.726795
# 1               462          W 22 St & 10 Ave               40.746920
# 2              2009  Catherine St & Monroe St               40.711174
# 3               294       Washington Square E               40.730494
# 4              3431           E 35 St & 3 Ave               40.746524
#
#    start_station_longitude  end_station_id         end_station_name  \
# 0               -73.996951             328  Watts St & Greenwich St
# ...
